# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
# - Replace with team member names and contributions.

# %% [markdown]
# # Research Question
# Replace with your research question.

# %% [markdown]
# ## Background and Prior Work
# Replace with your background research.

# %% [markdown]
# # Hypothesis
# Replace with your hypothesis.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
# Describe your datasets here.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('./modules')

import get_data

datafiles = [
 { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
 { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles, destination_directory='data/00-raw/')

# %% [markdown]
# ### Dataset #1

# %%
import pandas as pd

# Load dataset
df1 = pd.read_csv('data/00-raw/airline-safety.csv')

# Basic cleaning example
df1_clean = df1.copy()
df1_clean.columns = df1_clean.columns.str.lower().str.replace(' ', '_')

df1_clean.head()

# %% [markdown]
# ### Dataset #2

# %%
import pandas as pd

# Load dataset
df2 = pd.read_csv('data/00-raw/bad-drivers.csv')

# Basic cleaning
df2_clean = df2.copy()
df2_clean.columns = df2_clean.columns.str.lower().str.replace(' ', '_')

df2_clean.head()

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis

# %% [markdown]
# Describe what exploratory analysis you are performing and why.

# %%
import matplotlib.pyplot as plt

# Example visualization
df2_clean.hist(figsize=(10,6))
plt.show()

# %% [markdown]
# ## Ethics

# %% [markdown]
# Discuss ethical considerations.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Describe how your team plans to collaborate.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Provide your project timeline.
